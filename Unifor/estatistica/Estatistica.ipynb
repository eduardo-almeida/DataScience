# %%
import pandas as pd

# %% [markdown]
# # Produto Interno Bruto dos Municípios (2020)

# %%
dfProduto = pd.read_csv('data/produto_2020.csv')

# %%
dfProduto.head()
# Out:
#       Cód.                   Município  PIB (Mil Reais)  Impostos (Mil Reais)  \
# 0  1100015  Alta Floresta D'Oeste (RO)         570272.0               35109.0
# 1  1100023              Ariquemes (RO)        2818049.0              295656.0
# 2  1100031                 Cabixi (RO)         167190.0                7237.0
# 3  1100049                 Cacoal (RO)        2519353.0              274451.0
# 4  1100056             Cerejeiras (RO)         600670.0               89923.0
#
#    VA da agropecuária (Mil Reais)  VA da indústria (Mil Reais)  \
# 0                        203394.0                      20716.0
# 1                        199723.0                     404752.0
# 2                         81177.0                       5438.0
# 3                        236215.0                     275537.0
# 4                         94758.0                      23582.0
#
#    VA dos serviços (Mil Reais)  VA da administração pública (Mil Reais)
# ...

# %%
dfProdutoInterno['estado'] = dfProdutoInterno['Cód.'].astype(str).str[:2]

# %%
dfProdutoInterno.head()
# Out:
#       Cód.                   Município  PIB (Mil Reais)  Impostos (Mil Reais)  \
# 0  1100015  Alta Floresta D'Oeste (RO)         570272.0               35109.0
# 1  1100023              Ariquemes (RO)        2818049.0              295656.0
# 2  1100031                 Cabixi (RO)         167190.0                7237.0
# 3  1100049                 Cacoal (RO)        2519353.0              274451.0
# 4  1100056             Cerejeiras (RO)         600670.0               89923.0
#
#    VA da agropecuária (Mil Reais)  VA da indústria (Mil Reais)  \
# 0                        203394.0                      20716.0
# 1                        199723.0                     404752.0
# 2                         81177.0                       5438.0
# 3                        236215.0                     275537.0
# 4                         94758.0                      23582.0
#
#    VA dos serviços (Mil Reais)  VA da administração pública (Mil Reais) estado
# ...

# %%
dfEstadoProduto = dfProdutoInterno.groupby('estado')[['estado', 'Impostos (Mil Reais)', 'VA da agropecuária (Mil Reais)',
                                              'VA da agropecuária (Mil Reais)', 'VA da indústria (Mil Reais)',
                                              'VA dos serviços (Mil Reais)', 'VA da administração pública (Mil Reais)']].sum()

# %%
dfEstadoProduto.head(30)
# Out:
#         Impostos (Mil Reais)  VA da agropecuária (Mil Reais)  \
# estado
# 11                 5360627.0                       6891412.0
# 12                 1679901.0                        983532.0
# 13                20058422.0                       5114446.0
# 14                 1500037.0                       1000906.0
# 15                18021962.0                      19730651.0
# 16                 1256997.0                        339906.0
# 17                 4140893.0                       8033176.0
# 21                12287745.0                      11572446.0
# 22                 5805001.0                       5699080.0
# 23                20755740.0                       9508983.0
# 24                 7760854.0                       3010582.0
# 25                 7823994.0                       2823162.0
# 26                28538217.0                       8661857.0
# 27                 6060840.0                      12622357.0
# ...

# %% [markdown]
# # Estimativas de População (2020)

# %%
dfPopulacao = pd.read_csv('data/populacao_2020.csv')

# %%
dfPopulacao.head()
# Out:
#       Cód.                   Município  População (Pessoas)
# 0  1100015  Alta Floresta D'Oeste (RO)              22728.0
# 1  1100023              Ariquemes (RO)             109523.0
# 2  1100031                 Cabixi (RO)               5188.0
# 3  1100049                 Cacoal (RO)              85893.0
# 4  1100056             Cerejeiras (RO)              16204.0

# %% [markdown]
# # DTB - Divisão Territorial Brasileira

# %%
dfMunicipio = pd.read_csv('data/DTB_BRASIL_MUNICIPIO.csv')

# %%
dfMunicipio.head()
# Out:
#    UF   Nome_UF  Região Geográfica Intermediária  \
# 0  11  Rondônia                             1102
# 1  11  Rondônia                             1102
# 2  11  Rondônia                             1101
# 3  11  Rondônia                             1102
# 4  11  Rondônia                             1101
#
#   Nome Região Geográfica Intermediária  Região Geográfica Imediata  \
# 0                            Ji-Paraná                      110005
# 1                            Ji-Paraná                      110005
# 2                          Porto Velho                      110002
# 3                            Ji-Paraná                      110004
# 4                          Porto Velho                      110002
#
#   Nome Região Geográfica Imediata  Mesorregião Geográfica   Nome_Mesorregião  \
# 0                          Cacoal                       2  Leste Rondoniense
# 1                          Cacoal                       2  Leste Rondoniense
# ...

# %%
dfEstado = dfMunicipio.groupby('UF')[['UF', 'Nome_UF']]

# %%
dfEstado.head(30)
# Out:
#       UF           Nome_UF
# 0     11          Rondônia
# 1     11          Rondônia
# 2     11          Rondônia
# 3     11          Rondônia
# 4     11          Rondônia
# ...   ..               ...
# 5349  52             Goiás
# 5350  52             Goiás
# 5351  52             Goiás
# 5352  52             Goiás
# 5569  53  Distrito Federal
#
# [744 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

df = pd.DataFrame({'country': [177.0, 7.0, 4.0, 2.0, 2.0, 1.0, 1.0, 1.0]})
df.index = ['USA', 'Canada', 'Russia', 'UK', 'Belgium', 'Mexico', 'Germany', 'Denmark']
df = df.sort_values(by='country',ascending=False)
df["cumpercentage"] = df["country"].cumsum()/df["country"].sum()*100


fig, ax = plt.subplots()
ax.bar(df.index, df["country"], color="C0")
ax2 = ax.twinx()
ax2.plot(df.index, df["cumpercentage"], color="C1", marker="D", ms=7)
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="y", colors="C0")
ax2.tick_params(axis="y", colors="C1")
plt.show()

# %% [markdown]
# # Trabalho

# %%
dfProdutoPopulacao = pd.merge(dfProduto, dfPopulacao[['Cód.', 'População (Pessoas)']], how="inner", on=['Cód.'])

# %%
dfProdutoPopulacao.head()
# Out:
#       Cód.                   Município  PIB (Mil Reais)  Impostos (Mil Reais)  \
# 0  1100015  Alta Floresta D'Oeste (RO)         570272.0               35109.0
# 1  1100023              Ariquemes (RO)        2818049.0              295656.0
# 2  1100031                 Cabixi (RO)         167190.0                7237.0
# 3  1100049                 Cacoal (RO)        2519353.0              274451.0
# 4  1100056             Cerejeiras (RO)         600670.0               89923.0
#
#    VA da agropecuária (Mil Reais)  VA da indústria (Mil Reais)  \
# 0                        203394.0                      20716.0
# 1                        199723.0                     404752.0
# 2                         81177.0                       5438.0
# 3                        236215.0                     275537.0
# 4                         94758.0                      23582.0
#
#    VA dos serviços (Mil Reais)  VA da administração pública (Mil Reais)  \
# ...

# %%
dfProdutoPopulacaoEstado = pd.merge(dfProdutoPopulacao, dfMunicipio[['Código Município Completo']], how="inner", on=['Cód.', 'Código Município Completo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 dfProdutoPopulacaoEstado = pd.merge(dfProdutoPopulacao, dfMunicipio[[]], how="inner", on=['Cód.', 'Código Município Completo'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
# ...
